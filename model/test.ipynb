# %%
import sys
import json
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
def draw_matrix(data_json, target_column , filter ):
    # Chuyển đổi dữ liệu JSON thành DataFrame
		df = pd.DataFrame(data_json)
		X = df.drop(columns=[target_column])  # Loại bỏ cột mục tiêu khỏi đầu vào

		# Vẽ ma trận tương quan
		plt.figure(figsize=(10, 10))
		sns.heatmap(X.corr(), annot=True, cmap='coolwarm', fmt=".2f")
		plt.title('Correlation Matrix')
		plt.show()

# Lấy dữ liệu JSON từ stdin
if __name__ == "__main__":
		df = pd.read_csv('abflowData/orders.csv')
		input_data = df.to_json(orient='records')
		target_column = input_data["target_column"]
		data_json = input_data["data"]

		draw_matrix(data_json, target_column)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 16
#      14 df = pd.read_csv('abflowData/orders.csv')
#      15 input_data = df.to_json(orient='records')
# ---> 16 target_column = input_data["target_column"]
#      17 data_json = input_data["data"]
#      19 draw_matrix(data_json, target_column)
#
# TypeError: string indices must be integers, not 'str'
